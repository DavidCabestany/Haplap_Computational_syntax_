# %% [markdown]
# **Exercise 1: Train a simple trigram language model**
# ---
#
# -----
#
# In the first exercise, we´ll save the counts directly in a dictionary
#  which defaults to the smoothing factor (_note that this is not true smoothing
#  as it does not account for the denominator and therefore does not create a
#  true probability distribution, but it is enough to get started_)

# %%
import nltk
from collections import defaultdict
import numpy as np
import nltk.corpus
from nltk.corpus import brown

import numpy as np

# choose a small smoothing factor
smoothing_factor = 0.001
counts = defaultdict(lambda: defaultdict(lambda: smoothing_factor))

# %% [markdown]
# We'll also define two helper functions, one to get the log probability of
# a single trigram and the second to get the log probability of a full sentence

# %%
def logP(u, v, w):
    """
    Compute the log probability of a specific trigram
    """
    return np.log(counts[(u, v)][w]) - np.log(sum(counts[(u, v)]. values())) #this sums all the counts of the words


def sentence_logP(S):
    """
    Adds the special tokens to the beginning and end.
    Then calculates the sum of log probabilities of
    all trigrams in the sentence.
    """
    tokens = ['*', '*'] + S + ['STOP'] # beginning and ending tokens
    return sum([logP(u, v, w) for u, v, w in nltk.ngrams(tokens, 3)]) #

# %% [markdown]
# We then choose the corpus. We'll use the preprocessed Brown corpus (nltk.corpus.brown), which contains many domains.
# To see the domains, you can run brown.categories(). We also split this into train, dev, and test sets, which we will use throughout.

# %%
sentences = brown.sents(categories='news') 
dev_idx = int(len(sentences) * .7)
test_idx = int(len(sentences) * .8)
train = sentences[:dev_idx]
dev = sentences[dev_idx:test_idx]
test = sentences[test_idx:]

# %% [markdown]
# Finally, we'll collect the counts in the dictionary we set up before.

# %%
for sentence in train:
    # add the special tokens to the sentences
    tokens = ['*', '*'] + sentence + ['STOP ']
    for u, v, w in nltk.ngrams(tokens, 3):
        # update the counts
        counts[(u, v)][w] += 1

# %%
# Now that we have the model we can use it
print(sentence_logP("what?".split()))
# Out:
# -14.990150736468898

# %% [markdown]
# **Exercise 2: (3-5 minutes) **
# ---
#
# -----
#
# **Try and find the sentence (len > 10 tokens) with the highest probability**
#
# 1. What is the sentence with the highest probability you could find?
# 2. What is it's log probability?

# %%
high_prob = -99

for sentence in train+dev+test:
    if len(sentence) > 10:
        prob = sentence_logP(sentence)
        if prob > high_prob:
            high_prob = prob
            new_snce = sentence
            print(high_prob, sentence)
# Out:
# -25.037903239140228 ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.']
# -24.43941310706284 ['It', 'urged', 'that', 'the', 'city', '``', 'take', 'steps', 'to', 'remedy', "''", 'this', 'problem', '.']
# -24.32913733209239 ['Implementation', 'of', "Georgia's", 'automobile', 'title', 'law', 'was', 'also', 'recommended', 'by', 'the', 'outgoing', 'jury', '.']
# -23.58765723014937 ['``', 'Failure', 'to', 'do', 'this', 'will', 'continue', 'to', 'place', 'a', 'disproportionate', 'burden', "''", 'on', 'Fulton', 'taxpayers', '.']
# -22.733833913137126 ['On', 'other', 'matters', ',', 'the', 'jury', 'recommended', 'that', ':', '(', '1', ')']
# -18.169493306860495 ['It', 'listed', 'his', "wife's", 'age', 'as', '74', 'and', 'place', 'of', 'birth', 'as', 'Opelika', ',', 'Ala.', '.']
# -17.389261609679707 ['The', 'Hartsfield', 'home', 'is', 'at', '637', 'E.', 'Pelham', 'Rd.', 'Aj', '.']
# -16.419723424853753 ['It', 'was', 'marked', 'by', 'controversy', ',', 'anonymous', 'midnight', 'phone', 'calls', 'and', 'veiled', 'threats', 'of', 'violence', '.']
# -16.377936343847175 ['Wexler', 'has', 'denied', 'repeatedly', 'that', 'coercion', 'was', 'used', 'in', 'questioning', '.']
# -14.994720673907057 ['Policies', 'on', 'nuclear', 'test', 'ban', 'negotiations', 'were', 'reviewed', 'and', 'changed', '.']
# -14.993221550273574 ['Heating', 'is', 'by', 'individual', 'gas-fired', ',', 'forced', 'warm', 'air', 'systems', '.']
# -14.992224842199676 ['Of', '1,253', 'issues', 'traded', ',', '695', 'advanced', 'and', '354', 'declined', '.']
# -14.991225541626857 ['Gains', 'of', '2-3/4', 'were', 'posted', 'for', 'Teleprompter', 'and', 'Republic', 'Foil', '.']

# %% [markdown]
# **Exercise 3: Function for trigram model, define perplexity, find the best train domain (15-20 minutes) **
# ---
#
# -----

# %% [markdown]
# First, you'll need to define a function to train the trigram models. It should return the same kind of counts dictionary as in Exercise 1.

# %%
def estimate_lm(corpus, smoothing_factor=0.001):
    """This function takes a corpus and returns a trigram model (counts) trained on the corpus """
    counts = defaultdict(lambda: defaultdict(lambda: smoothing_factor))
    
    for sentence in train:
        # add the special tokens to the sentences
        tokens = ['*', '*'] + sentence + ['STOP ']
        for u, v, w in nltk.ngrams(tokens, 3):
            # update the counts
            counts[(u, v)][w] += 1
        
        
    return counts

# %% [markdown]
# Now, you'll need to define a function to measure perplexity, which is defined as the exp(total negative log likelihood / total_number_of_tokens). See https://web.stanford.edu/~jurafsky/slp3/3.pdf for more info.
#
# Luckily, we already have a function to get the log likelihood of a sentence (sentence_logP). So we can iterate over the sentences in a corpus, summing the log probability of each sentence, and keeping track of the total number of tokens. Finally, you can get the NEGATIVE log likelihood and average this, finally using np.exp to exponentiate the previous result.

# %%
def perplexity(corpus, train_counts):
    """
    Perplexity is defined as the exponentiated average negative log-likelihood of a sequence. 
    """
    total_log_likelihood = 0
    total_token_count = 0
    
    for sentence in corpus:
        total_log_likelihood += sentence_logP(sentence)
        total_token_count += len(sentence) 
        
    return np.exp(-total_log_likelihood/total_token_count)

# %%
test_data = [["I'm", 'not', 'giving', 'you', 'a', 'chance', ',', 'Bill', ',', 'but', 'availing', 'myself', 'of', 'your', 'generous', 'offer', 'of', 'assistance', '.'], ['Good', 'luck', 'to', 'you', "''", '.'], ['``', 'All', 'the', 'in-laws', 'have', 'got', 'to', 'have', 'their', 'day', "''", ',', 'Adam', 'said', ',', 'and', 'glared', 'at', 'William', 'and', 'Freddy', 'in', 'turn', '.'], ['Sweat', 'started', 'out', 'on', "William's", 'forehead', ',', 'whether', 'from', 'relief', 'or', 'disquietude', 'he', 'could', 'not', 'tell', '.'], ['Across', 'the', 'table', ',', 'Hamrick', 'saluted', 'him', 'jubilantly', 'with', 'an', 'encircled', 'thumb', 'and', 'forefinger', '.'], ['Nobody', 'else', 'showed', 'pleasure', '.'], ['Spike-haired', ',', 'burly', ',', 'red-faced', ',', 'decked', 'with', 'horn-rimmed', 'glasses', 'and', 'an', 'Ivy', 'League', 'suit', ',', 'Jack', 'Hamrick', 'awaited', 'William', 'at', 'the', "officers'", 'club', '.'], ['``', 'Hello', ',', 'boss', "''", ',', 'he', 'said', ',', 'and', 'grinned', '.'], ['``', 'I', 'suppose', 'I', 'can', 'never', 'expect', 'to', 'call', 'you', "'", 'General', "'", 'after', 'that', 'Washington', 'episode', "''", '.'], ['``', "I'm", 'afraid', 'not', "''", '.']]

# %% [markdown]
# Finally, use *estimate_lm()* to train LMs on each domain in brown.categories() and
# find which gives the lowest perplexity on test_data.
#
# 1. Which domain gives the best perplexity?
# 2. Can you think of a way to use language models to predict domain?

# %%
h_per = 99

for domain in brown.categories():
    train = brown.sents(categories=domain)
    counts = estimate_lm(train)
    perplex = perplexity(test_data, counts)
    
    if perplex < h_per:
        h_per = perplex
        dom = domain
result = "The corpus with lowest perplexity is {domi}, with a score of {h_perp}".format(domi=dom, h_perp=h_per)
print(result)
# Out:
# The corpus with lowest perplexity is romance, with a score of 6.077982934044908

# %%
# Out:
# defaultdict(<function __main__.estimate_lm.<locals>.<lambda>()>,
#             {('*',
#               '*'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'Dan': 6.0009999999999994,
#                           'He': 509.001,
#                           'If': 37.001,
#                           'But': 98.001,
#                           'Sometimes': 6.0009999999999994,
#                           'His': 68.001,
#                           'The': 392.001,
#                           'Each': 3.001,
#                           'each': 1.001,
#                           'Because': 2.001,
#                           'In': 40.001,
#                           'When': 43.001,
#                           'It': 135.001,
#                           'No': 21.000999999999998,
#                           'Morgan': 9.001,
#                           'Now': 28.000999999999998,
#                           'Reaching': 3.001,
#                           'They': 93.001,
#                           'She': 130.001,
#                           '``': 835.001,
#                           'Leaning': 2.001,
#                           "There's": 10.001,
#                           'Her': 22.000999999999998,
#                           'Any': 2.001,
#                           'Besides': 7.0009999999999994,
#                           'Both': 3.001,
#                           'We': 20.000999999999998,
#                           'Jones': 2.001,
#                           'Why': 8.001,
#                           "You'd": 3.001,
#                           'Could': 1.001,
#                           'There': 54.001,
#                           "He'd": 9.001,
#                           'I': 176.001,
#                           'Sharon': 1.001,
#                           "We'll": 3.001,
#                           'Your': 3.001,
#                           'How': 12.001,
#                           'This': 29.000999999999998,
#                           'You': 37.001,
#                           'then': 2.001,
#                           'Do': 3.001,
#                           "I'm": 11.001,
#                           "It's": 11.001,
#                           "You'll": 3.001,
#                           'Some': 6.0009999999999994,
#                           'Gavin': 6.0009999999999994,
#                           'Beneath': 1.001,
#                           'Clayton': 8.001,
#                           'Against': 2.001,
#                           'against': 2.001,
#                           "Gavin's": 3.001,
#                           'Just': 14.001,
#                           'My': 11.001,
#                           'And': 72.001,
#                           'Laurel': 1.001,
#                           'Oh': 5.0009999999999994,
#                           'God': 2.001,
#                           'That': 28.000999999999998,
#                           "Can't": 2.001,
#                           "I'll": 7.0009999999999994,
#                           'A': 71.001,
#                           'Two': 8.001,
#                           'Start': 1.001,
#                           'Help': 2.001,
#                           'Lived': 1.001,
#                           'Thirty-five': 1.001,
#                           'they': 4.0009999999999994,
#                           'Dawn': 1.001,
#                           'Then': 36.001,
#                           'Lester': 1.001,
#                           "That's": 8.001,
#                           'Joe': 1.001,
#                           'First': 4.0009999999999994,
#                           "Lester's": 1.001,
#                           'Cabot': 1.001,
#                           'Purvis': 1.001,
#                           'Thirty-six': 1.001,
#                           'in': 2.001,
#                           'Ahead': 1.001,
#                           'he': 6.0009999999999994,
#                           'With': 19.000999999999998,
#                           'California': 1.001,
#                           'Mike': 21.000999999999998,
#                           'Fiske': 1.001,
#                           'Julia': 1.001,
#                           'Light': 1.001,
#                           'Someone': 3.001,
#                           'About': 4.0009999999999994,
#                           'Evidently': 1.001,
#                           'All': 12.001,
#                           'Susan': 5.0009999999999994,
#                           'Dean': 5.0009999999999994,
#                           'Something': 4.0009999999999994,
#                           'Holding': 1.001,
#                           'One': 18.000999999999998,
#                           'Try': 1.001,
#                           "You're": 7.0009999999999994,
#                           'Watch': 1.001,
#                           'Take': 1.001,
#                           'These': 6.0009999999999994,
#                           'Durkin': 1.001,
#                           'Beyond': 2.001,
#                           'Ducking': 1.001,
#                           'An': 6.0009999999999994,
#                           'Shouldering': 1.001,
#                           'Snatching': 1.001,
#                           'Bursting': 1.001,
#                           'Powder': 1.001,
#                           'Bullets': 1.001,
#                           'Its': 4.0009999999999994,
#                           'Another': 4.0009999999999994,
#                           'Guerrillas': 2.001,
#                           'At': 23.000999999999998,
#                           'Calhoun': 1.001,
#                           'Hurry': 1.001,
#                           'Many': 2.001,
#                           'Lew': 1.001,
#                           'Hustle': 1.001,
#                           'Here': 4.0009999999999994,
#                           'Keep': 1.001,
#                           'Reverend': 3.001,
#                           "They'll": 4.0009999999999994,
#                           'Using': 1.001,
#                           'Fort': 1.001,
#                           'For': 25.000999999999998,
#                           'Oso': 4.0009999999999994,
#                           'Let': 5.0009999999999994,
#                           'Mr.': 3.001,
#                           'Hell': 4.0009999999999994,
#                           'Once': 11.001,
#                           '--': 3.001,
#                           'Before': 6.0009999999999994,
#                           'Well': 4.0009999999999994,
#                           'As': 27.000999999999998,
#                           'More': 1.001,
#                           'Still': 4.0009999999999994,
#                           'Surprisingly': 1.001,
#                           'What': 14.001,
#                           'Those': 3.001,
#                           "''": 9.001,
#                           '28': 1.001,
#                           'Attack': 1.001,
#                           'Gray': 3.001,
#                           'Our': 4.0009999999999994,
#                           'Montero': 3.001,
#                           'the': 7.0009999999999994,
#                           'Wildly': 1.001,
#                           'Buckets': 1.001,
#                           'although': 1.001,
#                           'Coyotes': 1.001,
#                           'Every': 5.0009999999999994,
#                           'under': 2.001,
#                           'Gradually': 3.001,
#                           'jagged': 1.001,
#                           'Next': 2.001,
#                           "Montero's": 2.001,
#                           'Kill': 1.001,
#                           'Lead': 1.001,
#                           'Far': 1.001,
#                           'Out': 6.0009999999999994,
#                           'there': 3.001,
#                           'Again': 3.001,
#                           'Men': 2.001,
#                           'Other': 1.001,
#                           'Above': 2.001,
#                           'Although': 6.0009999999999994,
#                           'Coming': 1.001,
#                           'Others': 1.001,
#                           'None': 3.001,
#                           'Maybe': 10.001,
#                           'Wilson': 3.001,
#                           'Be': 1.001,
#                           'Somebody': 4.0009999999999994,
#                           'his': 2.001,
#                           "You've": 3.001,
#                           'Is': 2.001,
#                           'Not': 17.000999999999998,
#                           'Mine': 1.001,
#                           "I've": 12.001,
#                           'Already': 3.001,
#                           'Six': 2.001,
#                           'good': 1.001,
#                           'livable': 1.001,
#                           '2': 1.001,
#                           'Kathy': 1.001,
#                           'Judith': 1.001,
#                           'Yes': 2.001,
#                           'all': 1.001,
#                           'Such': 4.0009999999999994,
#                           'only': 1.001,
#                           'Drifting': 1.001,
#                           'Squatting': 1.001,
#                           'Since': 2.001,
#                           'Baldness': 1.001,
#                           ')': 7.0009999999999994,
#                           'On': 8.001,
#                           'Everything': 1.001,
#                           'Noticing': 1.001,
#                           'Later': 4.0009999999999994,
#                           'Having': 3.001,
#                           'By': 6.0009999999999994,
#                           'Also': 3.001,
#                           'far': 1.001,
#                           'Though': 5.0009999999999994,
#                           'Large': 1.001,
#                           'Meanwhile': 1.001,
#                           'Cigarette': 1.001,
#                           'Past': 1.001,
#                           'Begging': 1.001,
#                           'indeed': 1.001,
#                           'Was': 3.001,
#                           'To': 8.001,
#                           'Barton': 11.001,
#                           'Rankin': 1.001,
#                           'Fred': 1.001,
#                           "Let's": 7.0009999999999994,
#                           'Powers': 3.001,
#                           'Deliberately': 1.001,
#                           'Even': 17.000999999999998,
#                           'Five': 5.0009999999999994,
#                           'Foster': 2.001,
#                           'Clyde': 1.001,
#                           'Kid': 1.001,
#                           "We've": 1.001,
#                           'Mitchell': 1.001,
#                           'Through': 2.001,
#                           'Carl': 1.001,
#                           'Mitch': 1.001,
#                           'Twenty': 2.001,
#                           'Did': 4.0009999999999994,
#                           'Dill': 2.001,
#                           'After': 13.001,
#                           "He's": 4.0009999999999994,
#                           "Dill's": 1.001,
#                           "Barton's": 2.001,
#                           'Donald': 1.001,
#                           'Chapter': 1.001,
#                           'Creighton': 1.001,
#                           'Their': 6.0009999999999994,
#                           'Hague': 3.001,
#                           'Fat': 1.001,
#                           'Ten': 4.0009999999999994,
#                           'Kodyke': 3.001,
#                           'Apparently': 2.001,
#                           'Normally': 1.001,
#                           'So': 17.000999999999998,
#                           'Slowly': 1.001,
#                           'Atonement': 1.001,
#                           'Perhaps': 5.0009999999999994,
#                           'Facing': 1.001,
#                           'Birds': 1.001,
#                           'Pamela': 4.0009999999999994,
#                           'today': 2.001,
#                           'she': 3.001,
#                           'Success': 1.001,
#                           'Unconcerned': 1.001,
#                           'Red': 3.001,
#                           'knowing': 1.001,
#                           'Indian': 1.001,
#                           'Bushes': 1.001,
#                           'Nevertheless': 2.001,
#                           'Silence': 3.001,
#                           'Where': 2.001,
#                           'stifled': 1.001,
#                           'clutched': 1.001,
#                           'Does': 1.001,
#                           'Twigs': 1.001,
#                           'bushes': 1.001,
#                           'tree': 1.001,
#                           'Miraculously': 3.001,
#                           'Beaming': 1.001,
#                           'Shu-tt': 1.001,
#                           'Lord': 4.0009999999999994,
#                           'Said': 1.001,
#                           'Looks': 1.001,
#                           "Wasn't": 1.001,
#                           'Print': 1.001,
#                           'Lips': 1.001,
#                           'Never': 3.001,
#                           'rather': 1.001,
#                           'Neither': 3.001,
#                           'teetering': 1.001,
#                           'sufficiently': 1.001,
#                           'Getting': 1.001,
#                           'that': 1.001,
#                           'Otherwise': 1.001,
#                           'Along': 2.001,
#                           'Joyce': 3.001,
#                           'Tom': 3.001,
#                           'McBride': 4.0009999999999994,
#                           'Moreover': 2.001,
#                           "Don't": 2.001,
#                           'Figger': 1.001,
#                           "An'": 1.001,
#                           'Oil-field': 1.001,
#                           'Beat': 1.001,
#                           'Somehow': 2.001,
#                           'Fear-maddened': 1.001,
#                           'Dimly': 2.001,
#                           'laughing': 1.001,
#                           'Nothing': 1.001,
#                           'Donna': 3.001,
#                           'Supper': 1.001,
#                           'Billie': 1.001,
#                           'Hank': 2.001,
#                           'Conchita': 3.001,
#                           'Elena': 1.001,
#                           'Tomas': 1.001,
#                           'Whatever': 3.001,
#                           'Certainly': 2.001,
#                           'Brannon': 9.001,
#                           'Finally': 3.001,
#                           'Give': 1.001,
#                           'Hernandez': 1.001,
#                           'Like': 4.0009999999999994,
#                           'During': 1.001,
#                           'Lighted': 1.001,
#                           'Hogan': 3.001,
#                           'Macklin': 3.001,
#                           'Come': 4.0009999999999994,
#                           'Get': 3.001,
#                           'Resignedly': 1.001,
#                           'Deputy': 2.001,
#                           'Miguel': 1.001,
#                           'Lewis': 1.001,
#                           'William': 1.001,
#                           'Rumors': 1.001,
#                           'Prosecutor': 1.001,
#                           'Publicly': 1.001,
#                           'Privately': 1.001,
#                           'Haying': 1.001,
#                           'Harnessing': 1.001,
#                           'Andy': 1.001,
#                           'Powell': 1.001,
#                           'Ross': 1.001,
#                           'Which': 1.001,
#                           'Keane': 1.001,
#                           'Houses': 1.001,
#                           'Jury': 1.001,
#                           '(': 4.0009999999999994,
#                           "Brenner's": 1.001,
#                           'Brenner': 2.001,
#                           'Tell': 3.001,
#                           'Vastly': 1.001,
#                           'Summers': 1.001,
#                           "Couldn't": 1.001,
#                           "Curt's": 2.001,
#                           'Probably': 1.001,
#                           'From': 8.001,
#                           'Curt': 17.000999999999998,
#                           'Horse': 1.001,
#                           'Presently': 2.001,
#                           'Jess': 11.001,
#                           'one': 2.001,
#                           'Who': 1.001,
#                           'Pistol-whipping': 1.001,
#                           "we're": 1.001,
#                           'Sweat': 2.001,
#                           'Somewhere': 3.001,
#                           "Jess's": 1.001,
#                           'Pain': 1.001,
#                           'so': 1.001,
#                           "What's": 3.001,
#                           'Blood': 2.001,
#                           'Turning': 1.001,
#                           'Leaving': 3.001,
#                           "We're": 2.001,
#                           'Black': 2.001,
#                           'Over': 4.0009999999999994,
#                           'Mrs.': 6.0009999999999994,
#                           'Jackson': 1.001,
#                           'Soon': 4.0009999999999994,
#                           'Damn': 2.001,
#                           'Nate': 2.001,
#                           'Sally': 1.001,
#                           'Slipping': 1.001,
#                           'Much': 1.001,
#                           'Seeing': 2.001,
#                           'Pa': 1.001,
#                           'Hez': 2.001,
#                           'Nor': 1.001,
#                           'Only': 5.0009999999999994,
#                           'Rod': 4.0009999999999994,
#                           'Gran': 2.001,
#                           'Captain': 1.001,
#                           'While': 5.0009999999999994,
#                           'Pat': 9.001,
#                           "Cobb's": 1.001,
#                           'Separating': 1.001,
#                           'Russ': 6.0009999999999994,
#                           'Suddenly': 6.0009999999999994,
#                           'Behind': 2.001,
#                           'Heading': 1.001,
#                           'Nerves': 1.001,
#                           'Fierce': 1.001,
#                           'Stevens': 2.001,
#                           'Muffling': 1.001,
#                           'Hitching': 1.001,
#                           'Climbing': 1.001,
#                           'Forced': 2.001,
#                           'Carmer': 1.001,
#                           'Looking': 2.001,
#                           'Halting': 1.001,
#                           'Less': 1.001,
#                           'Small': 1.001,
#                           'Cobb': 3.001,
#                           'Kneeling': 1.001,
#                           'Complying': 1.001,
#                           'Straightening': 1.001,
#                           'Inside': 1.001,
#                           "Carmer's": 1.001,
#                           'Count': 1.001,
#                           'Handing': 1.001,
#                           'Glowering': 1.001,
#                           'Pausing': 1.001,
#                           "It'll": 2.001,
#                           'Giving': 1.001,
#                           'Yet': 4.0009999999999994,
#                           'Nearing': 1.001,
#                           'but': 5.0009999999999994,
#                           'Hauling': 1.001,
#                           'Clapping': 1.001,
#                           'Setting': 1.001,
#                           'Whoever': 1.001,
#                           'Cursing': 1.001,
#                           'Dismounting': 1.001,
#                           'Toward': 1.001,
#                           'Leading': 1.001,
#                           'Swinging': 1.001,
#                           'Sweeping': 1.001,
#                           'Recklessly': 1.001,
#                           'Early': 2.001,
#                           'Cricket': 1.001,
#                           'Anything': 2.001,
#                           'Fleischman': 1.001,
#                           'Greg': 12.001,
#                           'Donovan': 1.001,
#                           'See': 1.001,
#                           "Greg's": 4.0009999999999994,
#                           'Underneath': 1.001,
#                           'Water': 1.001,
#                           'Stay': 1.001,
#                           'Todman': 3.001,
#                           'Visibility': 1.001,
#                           'Mercifully': 1.001,
#                           'Three': 3.001,
#                           'Twelve': 1.001,
#                           'Friend': 1.001,
#                           'Japanese': 1.001,
#                           'Lots': 1.001,
#                           'Belton': 1.001,
#                           "They're": 1.001,
#                           'Perfect': 1.001,
#                           'Eight': 1.001,
#                           'Please': 1.001,
#                           'Blind': 1.001,
#                           'Luck': 1.001,
#                           'Wingman': 1.001,
#                           'Cool': 1.001,
#                           'Adios': 1.001,
#                           'gauche': 1.001,
#                           'Autos': 1.001,
#                           'White-shirted': 1.001,
#                           'Squeezing': 1.001,
#                           'Johnson': 3.001,
#                           'Hardly': 1.001,
#                           'Quickly': 1.001,
#                           'it': 3.001,
#                           'Gracias': 1.001,
#                           'White': 1.001,
#                           'Prairie': 1.001,
#                           "Johnson's": 2.001,
#                           'Emptied': 1.001,
#                           'Teeth': 1.001,
#                           'High': 1.001,
#                           'Too': 4.0009999999999994,
#                           'with': 1.001,
#                           'Brakes': 1.001,
#                           'Big': 1.001,
#                           'Eyes': 1.001,
#                           'Plus': 1.001,
#                           'Shall': 3.001,
#                           'Would': 1.001,
#                           "Haven't": 1.001,
#                           'Man': 1.001,
#                           'Ah': 1.001,
#                           'Zing': 1.001,
#                           ',': 1.001,
#                           "They'd": 1.001,
#                           'even': 1.001,
#                           'Everybody': 1.001,
#                           'Anyway': 3.001,
#                           "She'd": 1.001,
#                           'Or': 2.001,
#                           'Seeming': 1.001,
#                           'Mmmm': 1.001,
#                           "Doesn't": 1.001,
#                           'Time': 1.001,
#                           'Softly': 1.001,
#                           'Warmly': 1.001,
#                           'However': 1.001,
#                           'Hot': 2.001,
#                           'Bryn': 1.001,
#                           'Four': 1.001,
#                           'Lights': 1.001,
#                           'Lieutenant': 1.001,
#                           'Rawlins': 1.001,
#                           'Present': 1.001,
#                           'Actually': 3.001,
#                           "How's": 1.001,
#                           'Accident': 1.001,
#                           'this': 1.001,
#                           'those': 1.001,
#                           'and': 4.0009999999999994,
#                           'True': 1.001,
#                           'or': 1.001,
#                           'some': 1.001,
#                           'Tomorrow': 1.001,
#                           'Shortly': 1.001,
#                           'Nicolas': 3.001,
#                           'Dammit': 1.001,
#                           "Meredith's": 2.001,
#                           'Should': 2.001,
#                           'Ballet': 1.001,
#                           'Mary': 7.0009999999999994,
#                           'Packing': 1.001,
#                           'Smiling': 1.001,
#                           'Families': 1.001,
#                           'Meredith': 2.001,
#                           'Rather': 1.001,
#                           'when': 2.001,
#                           'Singing': 1.001,
#                           'Soup': 1.001,
#                           'veal': 1.001,
#                           ';': 2.001,
#                           'Wine': 1.001,
#                           'Fruit': 1.001,
#                           'a': 1.001,
#                           'Opening': 1.001,
#                           'Steinhager': 1.001,
#                           'Kissing': 1.001,
#                           'Molten': 1.001,
#                           'suffocating': 1.001,
#                           'dust': 1.001,
#                           'Ben': 1.001,
#                           'Thank': 2.001,
#                           'Without': 1.001,
#                           'Frozen': 1.001,
#                           'Walls': 1.001,
#                           'Beaten': 1.001,
#                           'Clumps': 1.001,
#                           "Ben's": 1.001,
#                           'Of': 4.0009999999999994,
#                           'Hope': 1.001,
#                           'Sulphur': 1.001,
#                           'Brassnose': 4.0009999999999994,
#                           'Heave': 1.001,
#                           'our': 2.001,
#                           "We'd": 1.001,
#                           "I'd": 1.001,
#                           'Indeed': 1.001,
#                           'we': 1.001,
#                           'Often': 1.001,
#                           'Thirty': 1.001,
#                           'others': 1.001,
#                           '.': 1.001,
#                           'Karipo': 1.001,
#                           'Within': 2.001,
#                           'Few': 1.001,
#                           'Benson': 7.0009999999999994,
#                           'Ramey': 12.001,
#                           'Whenever': 1.001,
#                           'Horsely': 1.001,
#                           'Slender': 1.001,
#                           "Them's": 1.001,
#                           "Ramey's": 1.001,
#                           "She's": 3.001,
#                           'Strange': 2.001,
#                           'Seven': 1.001,
#                           "Isn't": 1.001,
#                           'Penny': 5.0009999999999994,
#                           'Asked': 1.001,
#                           "didn't": 1.001,
#                           'Keith': 6.0009999999999994,
#                           'Wing': 1.001,
#                           'Nowadays': 1.001,
#                           "Keith's": 1.001,
#                           'Peacocks': 1.001,
#                           'Mouse': 1.001,
#                           'Wild': 1.001,
#                           'Robinson': 1.001,
#                           'Waddell': 10.001,
#                           'Nitrogen': 1.001,
#                           'Personally': 1.001,
#                           'Old': 1.001,
#                           'went': 1.001,
#                           'Aloud': 1.001,
#                           'Shaffner': 1.001,
#                           'of': 1.001,
#                           'Herr': 1.001,
#                           'Fear': 1.001,
#                           'crossed': 1.001,
#                           'said': 1.001,
#                           'Folding': 1.001,
#                           'Make': 1.001,
#                           'Amen': 1.001,
#                           'Artie': 1.001,
#                           'Yesterday': 1.001,
#                           'tomorrow': 1.001,
#                           'Whichever': 1.001,
#                           'Gloom': 1.001,
#                           'Matsuo': 16.000999999999998,
#                           'Fresh': 1.001,
#                           'Apprehensively': 1.001,
#                           'Cautious': 1.001,
#                           'faint': 1.001,
#                           'whispers': 1.001,
#                           'leaning': 1.001,
#                           'Humiliation': 1.001,
#                           'Taking': 1.001,
#                           'Hush': 1.001,
#                           'Hand': 1.001,
#                           'Down': 1.001,
#                           'Reflex': 1.001,
#                           'Rifle': 1.001,
#                           'Heat': 1.001,
#                           'around': 1.001,
#                           'Maintaining': 1.001,
#                           'Sake': 1.001,
#                           'Drunk': 1.001,
#                           'Awkwardly': 1.001,
#                           'Wet': 1.001,
#                           'burned': 2.001,
#                           'Remembering': 1.001,
#                           'Popping': 1.001,
#                           'down': 1.001,
#                           'Chairs': 1.001,
#                           'Blue': 6.0009999999999994,
#                           'Most': 1.001,
#                           "Tilghman's": 1.001,
#                           'Tilghman': 5.0009999999999994,
#                           "He'll": 1.001,
#                           'Billy': 4.0009999999999994,
#                           'Several': 1.001,
#                           'Fifty': 1.001,
#                           'Citizens': 1.001,
#                           'Led': 1.001,
#                           'Bill': 1.001,
#                           'Directly': 1.001,
#                           'Seated': 1.001,
#                           'Thinking': 1.001,
#                           'Resisting': 1.001,
#                           'Leisurely': 1.001,
#                           'Back': 1.001,
#                           'Wiley': 1.001,
#                           'Miss': 2.001,
#                           'Tall': 1.001,
#                           'School': 1.001,
#                           'Outside': 1.001,
#                           'Daddy': 1.001,
#                           'Charles': 3.001,
#                           'Jack': 3.001,
#                           'Occasionally': 1.001,
#                           'Lithe': 1.001,
#                           'Col.': 1.001,
#                           'Johnny': 1.001,
#                           'Delphine': 4.0009999999999994,
#                           'Madame': 1.001,
#                           'Shy': 1.001,
#                           'Lifting': 1.001,
#                           'Satisfied': 1.001,
#                           'Prieur': 1.001,
#                           'Aristide': 1.001,
#                           'Dr.': 4.0009999999999994,
#                           'Dandy': 1.001,
#                           'Really': 1.001,
#                           'Had': 1.001,
#                           'Airless': 1.001,
#                           'Feebly': 1.001,
#                           'Convulsively': 1.001,
#                           'Guests': 1.001,
#                           'Ruffians': 1.001,
#                           'Ever': 2.001,
#                           'Till': 1.001,
#                           'at': 1.001,
#                           'Hair': 1.001,
#                           'Zingggg-O': 1.001,
#                           'Curly': 1.001,
#                           'Feathertop': 6.0009999999999994,
#                           'Slug': 1.001,
#                           'Hmm': 1.001,
#                           'Kitty': 2.001,
#                           'Ernie': 8.001,
#                           'Joviality': 1.001,
#                           "C'mon": 1.001,
#                           'Cappy': 3.001,
#                           'Charcoal': 1.001,
#                           'Almost': 1.001,
#                           'Nice': 1.001,
#                           "Cappy's": 1.001,
#                           "Ernie's": 1.001,
#                           'Real': 1.001,
#                           'Road': 1.001}),
#              ('*',
#               'Dan'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'Morgan': 2.001,
#                           'could': 1.001,
#                           'affirmed': 1.001,
#                           'asked': 1.001,
#                           'grinned': 1.001}),
#              ('Dan',
#               'Morgan'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'told': 1.001,
#                           "''": 1.001,
#                           '.': 1.001}),
#              ('Morgan',
#               'told'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'himself': 1.001}),
#              ('told',
#               'himself'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'he': 2.001,
#                           'desperately': 1.001,
#                           'in': 1.001}),
#              ('himself',
#               'he'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'would': 1.001,
#                           'had': 1.001}),
#              ('he',
#               'would'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'forget': 1.001,
#                           'do': 2.001,
#                           'help': 1.001,
#                           'never': 3.001,
#                           'have': 3.001,
#                           'let': 1.001,
#                           'address': 1.001,
#                           'understand': 1.001,
#                           'ever': 1.001,
#                           'come': 1.001,
#                           'join': 1.001,
#                           'spin': 1.001,
#                           'try': 1.001,
#                           'realize': 1.001,
#                           'watch': 1.001,
#                           'always': 1.001,
#                           'return': 1.001,
#                           'rot': 1.001,
#                           'stop': 1.001,
#                           'be': 3.001,
#                           'turn': 1.001,
#                           'run': 1.001,
#                           'look': 1.001,
#                           'say': 1.001}),
#              ('would',
#               'forget'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'Ann': 1.001}),
#              ('forget',
#               'Ann'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'Turner': 1.001}),
#              ('Ann',
#               'Turner'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'.': 1.001}),
#              ('Turner',
#               '.'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'STOP ': 1.001}),
#              ('*',
#               'He'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'was': 50.001,
#                           'certainly': 1.001,
#                           'found': 5.0009999999999994,
#                           'had': 50.001,
#                           'could': 7.0009999999999994,
#                           'stopped': 2.001,
#                           'cleaned': 1.001,
#                           "didn't": 8.001,
#                           'asked': 8.001,
#                           'picked': 2.001,
#                           'put': 2.001,
#                           'stood': 4.0009999999999994,
#                           'brought': 1.001,
#                           'dismissed': 1.001,
#                           "wasn't": 2.001,
#                           "hadn't": 4.0009999999999994,
#                           'said': 15.001,
#                           'caught': 3.001,
#                           'told': 1.001,
#                           'carried': 2.001,
#                           'nodded': 2.001,
#                           'whispered': 1.001,
#                           'got': 3.001,
#                           'wiped': 2.001,
#                           'burst': 1.001,
#                           'approached': 1.001,
#                           'saw': 6.0009999999999994,
#                           'worked': 1.001,
#                           'remembered': 3.001,
#                           "wouldn't": 2.001,
#                           'treats': 1.001,
#                           'turned': 6.0009999999999994,
#                           'meant': 2.001,
#                           'made': 4.0009999999999994,
#                           'swung': 3.001,
#                           'fled': 1.001,
#                           'looked': 8.001,
#                           'rode': 2.001,
#                           'did': 6.0009999999999994,
#                           'knew': 7.0009999999999994,
#                           'would': 5.0009999999999994,
#                           'and': 5.0009999999999994,
#                           'handed': 3.001,
#                           'added': 1.001,
#                           'felt': 3.001,
#                           'kissed': 1.001,
#                           'released': 2.001,
#                           'snorted': 1.001,
#                           'kept': 1.001,
#                           'wanted': 6.0009999999999994,
#                           'might': 2.001,
#                           'located': 1.001,
#                           'tried': 1.001,
#                           'demanded': 2.001,
#                           'protested': 1.001,
#                           'lifted': 2.001,
#                           'darted': 1.001,
#                           'scuttled': 1.001,
#                           'crouched': 1.001,
#                           'crawled': 1.001,
#                           'set': 1.001,
#                           'shouldered': 1.001,
#                           'hovered': 1.001,
#                           'peered': 1.001,
#                           'dropped': 4.0009999999999994,
#                           'brushed': 1.001,
#                           'shook': 2.001,
#                           'started': 6.0009999999999994,
#                           'jerked': 1.001,
#                           'sold': 2.001,
#                           'took': 8.001,
#                           'grabbed': 1.001,
#                           'raised': 1.001,
#                           'watched': 2.001,
#                           'side-stepped': 1.001,
#                           'scrubbed': 1.001,
#                           'finished': 1.001,
#                           'spoke': 2.001,
#                           'wore': 5.0009999999999994,
#                           'pointed': 2.001,
#                           "couldn't": 3.001,
#                           'dumped': 1.001,
#                           'too': 1.001,
#                           'wants': 1.001,
#                           'lived': 1.001,
#                           'ran': 2.001,
#                           'threw': 2.001,
#                           'supervised': 1.001,
#                           'pulled': 1.001,
#                           'broke': 1.001,
#                           'opened': 3.001,
#                           'waited': 3.001,
#                           'grinned': 2.001,
#                           'went': 4.0009999999999994,
#                           'slid': 1.001,
#                           'seemed': 2.001,
#                           'himself': 1.001,
#                           'flung': 1.001,
#                           ',': 1.001,
#                           'hated': 1.001,
#                           'held': 6.0009999999999994,
#                           'hardly': 1.001,
#                           'swore': 1.001,
#                           'came': 2.001,
#                           'strode': 1.001,
#                           'raged': 1.001,
#                           'exploded': 1.001,
#                           'never': 1.001,
#                           'slumped': 1.001,
#                           'immediately': 1.001,
#                           'heaved': 1.001,
#                           'echoed': 1.001,
#                           'evidently': 1.001,
#                           'moistened': 1.001,
#                           'paused': 1.001,
#                           'moved': 5.0009999999999994,
#                           'studied': 1.001,
#                           'slapped': 1.001,
#                           'reached': 2.001,
#                           'drew': 2.001,
#                           'retreated': 1.001,
#                           'slammed': 2.001,
#                           'stepped': 1.001,
#                           'lurched': 1.001,
#                           'backed': 1.001,
#                           'let': 2.001,
#                           'shoved': 1.001,
#                           'stooped': 1.001,
#                           'shouted': 1.001,
#                           'bellowed': 1.001,
#                           'tramped': 1.001,
#                           'fought': 2.001,
#                           'tightened': 2.001,
#                           "ain't": 1.001,
#                           'heard': 2.001,
#                           'dashed': 1.001,
#                           'clambered': 1.001,
#                           'wondered': 1.001,
#                           'possessed': 1.001,
#                           'shivered': 1.001,
#                           'spread': 1.001,
#                           'thought': 5.0009999999999994,
#                           'narrowed': 1.001,
#                           'pushed': 2.001,
#                           'hit': 1.001,
#                           'hauled': 1.001,
#                           'filled': 1.001,
#                           'already': 1.001,
#                           'inwardly': 1.001,
#                           'used': 1.001,
#                           'began': 2.001,
#                           'half': 2.001,
#                           'sneezed': 1.001,
#                           'blew': 1.001,
#                           'spit': 1.001,
#                           'belched': 2.001,
#                           'flexed': 1.001,
#                           'commanded': 1.001,
#                           'removed': 1.001,
#                           'spat': 1.001,
#                           'cleared': 2.001,
#                           'unlashed': 1.001,
#                           'cleansed': 1.001,
#                           'replenished': 1.001,
#                           'tilted': 1.001,
#                           'stared': 3.001,
#                           'winced': 1.001,
#                           'darkened': 1.001,
#                           'hollered': 1.001,
#                           'sputtered': 1.001,
#                           'examined': 1.001,
#                           'doubted': 1.001,
#                           'gripped': 1.001,
#                           'poured': 1.001,
#                           'furled': 1.001,
#                           'sprinted': 1.001,
#                           'then': 1.001,
#                           'speaks': 1.001,
#                           'chatted': 1.001,
#                           'moaned': 1.001,
#                           'walked': 2.001,
#                           'smiled': 1.001,
#                           'became': 1.001,
#                           'enjoyed': 2.001,
#                           'stressed': 1.001,
#                           'even': 1.001,
#                           'sloshed': 1.001,
#                           'pressed': 1.001,
#                           'crossed': 2.001,
#                           'murmured': 1.001,
#                           'sighed': 1.001,
#                           'decided': 1.001,
#                           'strained': 1.001,
#                           'squatted': 1.001,
#                           'sniffed': 1.001,
#                           'must': 2.001,
#                           'ceased': 1.001,
#                           'cupped': 1.001,
#                           'aimed': 1.001,
#                           'performed': 1.001,
#                           'capped': 1.001,
#                           'reminded': 1.001,
#                           'leered': 1.001,
#                           'straightened': 1.001,
#                           'fired': 1.001,
#                           'sized': 1.001,
#                           'called': 1.001,
#                           'slipped': 1.001,
#                           'strolled': 1.001,
#                           'left': 1.001,
#                           'hung': 1.001,
#                           'jumped': 1.001,
#                           'ate': 1.001,
#                           'considered': 1.001,
#                           'simply': 1.001,
#                           'scarcely': 1.001,
#                           'chuckled': 1.001,
#                           'showed': 1.001,
#                           'proudly': 1.001,
#                           'gaped': 1.001,
#                           'deserves': 1.001,
#                           'bounced': 1.001,
#                           'liked': 1.001,
#                           'mused': 1.001,
#                           'ripped': 1.001,
#                           'guzzled': 1.001,
#                           'advanced': 1.001,
#                           'fisted': 1.001}),
#              ('He',
#               'was'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'well': 1.001,
#                           'silent': 1.001,
#                           'thinking': 3.001,
#                           'too': 1.001,
#                           ',': 1.001,
#                           'partially': 1.001,
#                           'naked': 1.001,
#                           'dead': 1.001,
#                           'riding': 1.001,
#                           'losing': 1.001,
#                           'taken': 1.001,
#                           'shaking': 1.001,
#                           'tall': 1.001,
#                           'a': 5.0009999999999994,
#                           'proud': 1.001,
#                           'handsome': 1.001,
#                           'an': 1.001,
#                           'readying': 1.001,
#                           'in': 2.001,
#                           'only': 1.001,
#                           'puffing': 1.001,
#                           'uttering': 1.001,
#                           'finally': 1.001,
#                           'about': 2.001,
#                           'looking': 1.001,
#                           'determined': 1.001,
#                           'asking': 1.001,
#                           'very': 1.001,
#                           'aware': 1.001,
#                           'on': 1.001,
#                           'frowning': 1.001,
#                           'disturbed': 1.001,
#                           'most': 1.001,
#                           'bearded': 1.001,
#                           'the': 1.001,
#                           'possessive': 1.001,
#                           'gifted': 1.001,
#                           '--': 1.001,
#                           'pressed': 1.001,
#                           'less': 1.001,
#                           'big': 2.001}),
#              ('was',
#               'well'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'rid': 1.001,
#                           'below': 1.001,
#                           'made': 1.001}),
#              ('well',
#               'rid'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'of': 1.001}),
#              ('rid',
#               'of'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'her': 1.001,
#                           'that': 1.001,
#                           'it': 1.001}),
#              ('of',
#               'her'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'.': 2.001,
#                           'coat': 1.001,
#                           'horse': 1.001,
#                           'mother': 1.001,
#                           'movements': 1.001,
#                           'great-grandfather': 1.001,
#                           'slacks': 1.001,
#                           'previous': 1.001,
#                           'heart': 1.001,
#                           'mental': 1.001,
#                           'benighted': 1.001,
#                           'direction': 1.001,
#                           ',': 2.001,
#                           'attempt': 1.001,
#                           'blouse': 1.001,
#                           'skin': 1.001,
#                           'mouth': 2.001,
#                           'jaws': 1.001,
#                           'eyes': 2.001,
#                           'brain': 1.001,
#                           'words': 1.001,
#                           'concern': 1.001,
#                           'gaiety': 1.001,
# ...
#                           ',': 1.001,
#                           'against': 1.001,
#                           'rushed': 1.001,
#                           'that': 1.001,
#                           '.': 2.001,
#                           'begin': 1.001,
#                           'discipline': 1.001}),
#              ('water',
#               'from'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'the': 2.001,
#                           'a': 1.001,
#                           'his': 1.001}),
#              ('spring',
#               'which'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'he': 1.001}),
#              ('which',
#               'he'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'poured': 1.001,
#                           'felt': 1.001,
#                           'sped': 1.001,
#                           'placed': 1.001,
#                           'unfastened': 1.001,
#                           'sometimes': 1.001,
#                           'went': 1.001,
#                           'and': 2.001}),
#              ('he',
#               'poured'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'into': 1.001}),
#              ('poured',
#               'into'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'the': 1.001}),
#              ('the',
#               'copper'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'boiler': 1.001}),
#              ('copper',
#               'boiler'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'that': 1.001}),
#              ('boiler',
#               'that'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'he': 1.001}),
#              ('had',
#               'placed'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'on': 1.001,
#                           'him': 1.001}),
#              ('placed',
#               'on'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'the': 1.001}),
#              ('the',
#               'stove'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'.': 1.001}),
#              ('stove',
#               '.'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'STOP ': 2.001}),
#              ('He',
#               'brought'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'his': 1.001}),
#              ('brought',
#               'his'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'Winchester': 1.001,
#                           'horse': 1.001}),
#              ('in',
#               'from'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'the': 3.001}),
#              (',',
#               'then'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'faced': 1.001,
#                           'started': 1.001,
#                           'sat': 1.001,
#                           'he': 1.001,
#                           'stared': 1.001,
#                           'rose': 1.001,
#                           'it': 1.001,
#                           'spread': 1.001,
#                           'run': 1.001,
#                           'let': 2.001,
#                           'the': 1.001,
#                           'went': 1.001,
#                           'bark': 1.001,
#                           'walked': 1.001,
#                           'asked': 1.001,
#                           'hers': 1.001,
#                           'his': 1.001,
#                           'spent': 1.001,
#                           'tried': 1.001,
#                           'climbed': 2.001,
#                           'noticed': 1.001,
#                           'as': 1.001,
#                           'turned': 1.001,
#                           "''": 1.001,
#                           'swirled': 1.001,
#                           'bursting': 1.001,
#                           'Lou': 1.001,
#                           ',': 1.001,
#                           'ran': 1.001,
#                           'soak': 1.001,
#                           'sinking': 1.001,
#                           'stopped': 1.001,
#                           'I': 1.001,
#                           'headed': 1.001,
#                           'turning': 1.001,
#                           'fled': 1.001,
#                           'slowed': 1.001,
#                           'opened': 1.001}),
#              ('then',
#               'faced'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'the': 1.001}),
#              ('faced',
#               'the'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'boy': 1.001,
#                           'terrible': 1.001}),
#              ('boy',
#               '.'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'STOP ': 7.0009999999999994}),
#              ('``',
#               'Who'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'are': 2.001,
#                           'was': 1.001}),
#              ('Who',
#               'are'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'you': 2.001}),
#              ('are',
#               'you'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'and': 1.001,
#                           'doing': 2.001,
#                           '?': 1.001,
#                           "''": 1.001,
#                           'going': 1.001,
#                           'trying': 1.001}),
#              ('you',
#               'and'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'what': 1.001,
#                           'your': 1.001,
#                           'me': 3.001,
#                           'I': 1.001,
#                           'Arbuckle': 1.001,
#                           "Rod's": 1.001,
#                           'that': 1.001,
#                           'Artie': 1.001}),
#              ('and',
#               'what'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'happened': 1.001,
#                           'made': 1.001,
#                           'Charles': 1.001}),
#              ('what',
#               'happened'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'to': 3.001}),
#              ('happened',
#               'to'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'you': 1.001,
#                           'Missy': 1.001,
#                           'them': 1.001,
#                           'Gruller': 1.001,
#                           'anyone': 1.001,
#                           'Sally': 1.001,
#                           'him': 1.001}),
#              ('to',
#               'you'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {"''": 1.001,
#                           ',': 1.001,
#                           '.': 1.001,
#                           'like': 1.001}),
#              ('asked',
#               '.'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'STOP ': 10.001}),
#              ('``',
#               "I'm"): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'Billy': 2.001,
#                           'a': 2.001,
#                           'Dan': 1.001,
#                           'sorry': 2.001,
#                           'going': 2.001,
#                           'not': 1.001,
#                           'telling': 1.001,
#                           'starting': 1.001,
#                           'just': 2.001,
#                           'gonna': 1.001,
#                           'pregnant': 1.001}),
#              ("I'm",
#               'Billy'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'Jones': 1.001,
#                           'Tilghman': 1.001}),
#              ('Billy',
#               'Jones'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {"''": 1.001}),
#              ('Jones',
#               "''"): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {',': 1.001}),
#              ('boy',
#               'answered'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'.': 1.001}),
#              ('answered',
#               '.'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'STOP ': 1.001}),
#              ('``',
#               "That's"): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'my': 3.001,
#                           'all': 3.001,
#                           'a': 1.001,
#                           'why': 1.001,
#                           'the': 2.001,
#                           'what': 1.001,
#                           'right': 1.001}),
#              ("That's",
#               'my'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'wife': 1.001,
#                           'spare': 1.001,
#                           'boy': 1.001}),
#              ('my',
#               'wife'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'Sharon': 1.001}),
#              ('wife',
#               'Sharon'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'.': 1.001}),
#              ('Sharon',
#               '.'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'STOP ': 1.001}),
#              ('*',
#               'We'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'ran': 1.001,
#                           "haven't": 2.001,
#                           'may': 1.001,
#                           'want': 1.001,
#                           "don't": 2.001,
#                           'can': 1.001,
#                           'were': 5.0009999999999994,
#                           'made': 1.001,
#                           "couldn't": 1.001,
#                           'pulled': 1.001,
#                           'are': 2.001,
#                           'spoke': 1.001,
#                           'run': 1.001}),
#              ('We',
#               'ran'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'out': 1.001}),
#              ('ran',
#               'out'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'of': 1.001,
#                           '.': 2.001}),
#              ('out',
#               'of'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'money': 1.001,
#                           'the': 23.000999999999998,
#                           'his': 6.0009999999999994,
#                           'this': 1.001,
#                           'here': 5.0009999999999994,
#                           'reach': 1.001,
#                           'him': 2.001,
#                           'sight': 4.0009999999999994,
#                           'bed': 1.001,
#                           'Folsom': 1.001,
#                           'line': 1.001,
#                           'that': 3.001,
#                           'there': 1.001,
#                           'its': 1.001,
#                           'shape': 1.001,
#                           "Carmer's": 1.001,
#                           'showers': 1.001,
#                           'New': 1.001,
#                           'Central': 1.001,
#                           'college': 1.001,
#                           'my': 1.001,
#                           'a': 2.001,
#                           'town': 1.001,
#                           'Ma': 1.001,
#                           'breath': 1.001,
#                           'your': 1.001,
#                           'her': 2.001,
#                           'it': 1.001}),
#              ('of',
#               'money'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'and': 1.001,
#                           'back': 1.001,
#                           "''": 1.001}),
#              ('money',
#               'and'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'we': 1.001}),
#              ('and',
#               'we'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {"haven't": 1.001,
#                           "can't": 1.001,
#                           'would': 1.001,
#                           'both': 2.001,
#                           'have': 1.001}),
#              ('we',
#               "haven't"): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'eaten': 1.001,
#                           'I': 1.001}),
#              ("haven't",
#               'eaten'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'for': 1.001}),
#              ('eaten',
#               'for'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'two': 1.001}),
#              ('for',
#               'two'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'days': 1.001}),
#              ('two',
#               'days'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {"''": 1.001}),
#              ('days',
#               "''"): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'.': 1.001,
#                           ',': 2.001}),
#              ('``',
#               'What'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'are': 3.001,
#                           'would': 1.001,
#                           'did': 2.001,
#                           'else': 2.001,
#                           'must': 1.001,
#                           'for': 1.001,
#                           'is': 4.0009999999999994,
#                           'the': 1.001,
#                           'about': 1.001,
#                           'luck': 1.001,
#                           'were': 1.001,
#                           'a': 1.001,
#                           'happens': 1.001,
#                           'outfit': 1.001,
#                           'does': 1.001,
#                           'happened': 1.001,
#                           'do': 1.001}),
#              ('What',
#               'are'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'you': 3.001}),
#              ('you',
#               'doing'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'here': 1.001,
#                           'out': 1.001}),
#              ('doing',
#               'here'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {"''": 2.001}),
#              ('here',
#               "''"): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'?': 4.0009999999999994,
#                           '.': 8.001,
#                           '!': 1.001,
#                           ',': 1.001}),
#              ('``',
#               'Are'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'we': 1.001,
#                           'you': 4.0009999999999994}),
#              ('Are',
#               'we'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'in': 1.001}),
#              ('we',
#               'in'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {'Wyoming': 1.001}),
#              ('in',
#               'Wyoming'): defaultdict(<function __main__.estimate_lm.<locals>.<lambda>.<locals>.<lambda>()>, {"''": 1.001,
#                           'seemed': 1.001,
#                           '.': 1.001}),
#              ...})

# %% [markdown]
# **Exercise 4: Generation **
# ---
#
# -----

# %% [markdown]
# For the next exercise, you will need to generate 10 sentences for each domain in the Brown corpus. The first thing we need is code to be able to sample the next word in a trigram. We'll do this by creating a probability distribution over the values in our trigram counts. Remember that each key in the dictionary is a tuple (u, v) and that the values is another dictionary with the count of the continuation w: count. Therefore, we can create a numpy array with the continuation values and divide by the sum of values to get a distribution. Finally, we can use np.random.multinomial to sample from this distribution.

# %%
def sample_next_word(u, v):
    keys, values = zip(* counts[(u, v)]. items())
    # convert values to np.array
    values = np.array(values)
    # divide by sum to create prob. distribution
    values /= values.sum()  
    # return the key (continuation token) for the sample with the highest probability
    return keys[np.argmax(np.random.multinomial(1, values))]

# %% [markdown]
# Now we can create a function that will generate text using our trigram model. You will need to start out with the two special tokens we used to train the model, and continue adding to this output, sampling the next word at each timestep. If the word sampled is the end token ('STOP'), then stop the generation and return the sequence as a string.

# %%
def generate():
    """
    Sequentially generates text using sample_next_word().
    When the token generated is 'STOP', it returns the generated tokens as a string,
    removing the start and end special tokens.
    """
    result = ['*', '*']
    
    # Finish the code here

# %% [markdown]
# Finally, use the code above to generate 10 sentences per domain in the Brown corpus.
#
# 1. Do you see any correlation between perplexity scores and generated text?

# %% [markdown]
# **Exercise 5: Smoothing **
# ---
#
# -----

# %% [markdown]
# So far, we have been using a kind of stupid smoothing technique, giving up entirely on computing an actual probability distribution. For this section, let's implement a correct version of Laplace smoothing. You'll need to keep track of the vocabulary as well, and don't forget to add the special tokens.

# %%
def estimate_lm_smoothed(corpus, alpha=1):
    counts = defaultdict(lambda: defaultdict(lambda: alpha))
    vocab = set()
    
    # Finish the code here

    return counts, vocab

# %% [markdown]
# The main change is not in how we estimate the counts, but in how we calculate log probability for each trigram.
# Specifically, we need to add the size_of_the_vocabulary * alpha to the denominator.

# %%
def logP_smoothed(u, v, w, V, alpha=1):
    # Finish the code here
    pass

def sentence_logP_smoothed(S, V, alpha=1):
    """
    Adds the special tokens to the beginning and end.
    Then calculates the sum of log probabilities of
    all trigrams in the sentence using logP_smoothed.
    """
    # Finish the code here
    pass

def perplexity_smoothed(corpus, V, alpha=1):
    """
    Perplexity is defined as the exponentiated average negative log-likelihood of a sequence. In this case, we approximate perplexity over the full corpus as an average of sentence-wise perplexity scores.
    """
    # Finish the code here
    pass

# %% [markdown]
# Now train s_counts and vocab and compare perplexity with the original version on the heldout test set.

# %% [markdown]
# **Exercise 6: Interpolation**
# ---
#
# -----

# %% [markdown]
# To be able to interpolate unigram, bigram, and trigram models, we first need to train them. So here you need to make a function that takes 1) a corpus and 2) an n-gram (1,2,3) and 3) a smoothing factor and returns the counts and vocabulary. Notice that for the unigram model, you will have to set up the dictionary in a different way than we have done until now.

# %%
def estimate_ngram(corpus, N=3, smoothing_factor=1):
    vocab = set(['*', 'STOP'])
    if N > 1:
        # set up the counts like before
        counts = None
    else:
        # set them up as necessary for the unigram model
        counts = None
        
    # Finish the code here
    return counts, vocab

# %% [markdown]
# You will also need separate functions to get the log probability for each ngram.

# %%
def logP_trigram(counts, u, v, w, vocab, alpha=1):
    # Finish the code here
    pass


def logP_bigram(counts, u, v, vocab, alpha=1):
    # Finish the code here
    pass

def logP_unigram(counts, u, vocab, alpha=1):
    # Finish the code here
    pass

# %% [markdown]
# In this case, the main change is in calculating the log probability of the sentence.

# %%
def sentence_interpolated_logP(S, vocab, uni_counts, bi_counts, tri_counts, lambdas=[0.5, 0.3, 0.2]):
    tokens = ['*', '*'] + S + ['STOP']
    prob = 0
    for u, v, w in nltk.ngrams(tokens, 3):
        # Finish the code here
        # Calculate the log probabilities for each ngram and then multiply them by the lambdas and sum them.
        pass
    return prob

def interpolated_perplexity(corpus, vocab, uni_counts, bi_counts, tri_counts, smoothing_factor=1, lambdas=[0.5, 0.3, 0.2]):
    """
    Perplexity is defined as the exponentiated average negative log-likelihood of a sequence. 
    In this case, we approximate perplexity over the full corpus as an average of sentence-wise perplexity scores.
    """
    p = 0
    # Finish the code here
    
    pass

# %% [markdown]
# Finally, train unigram, bigram, and trigram models and computer the perplexity of the interpolated model on the test set.

# %% [markdown]
# **Exercise 7: Build a simple spelling corrector**
# ---
#
# -----

# %% [markdown]
# In this section, we will build a simple spelling corrector with two components: 1) a dictionary of common spelling errors which will allow us to create possible hypothesis sentences and 2) a language model to filter the most likely sentence.

# %%
common_errors = {"ei": "ie",  # acheive: achieve
                 "ie": "ei",  # recieve: receive
                 "ant": "ent",  # apparant: apparent
                 "m": "mm",  # accomodate: accommodate
                 "s": "ss",  # profesional: professional
                 "teh": "the",
                 "too": "to",
                 "their": "there",
                 "there": "they're"
                 }

# %%
test_set = ["I do not know who recieved it".split(),
            "That is not profesional".split(),
            "we saw teh man running".split(),
            "We tried too help them".split(),
            ]

# %% [markdown]
# For the spell checker,

# %%
def spell_check(sent, common_errors):
    sents = []
    probs = []
    sents.append(sent)
    probs.append(sentence_logP(sent))
    
    # create new hypothesis sentences by recursively applying all possible spelling mistakes to 
    # each token in the sentence. If the new sentence is not the same as the original, append
    # it to sents and compute its probability and append it to probs.
    for i, token in enumerate(sent):
        for error, correct in common_errors.items():
            
            # Finish the code here
            pass
        
    # Finally take the argmax of the probabilities and return that sentence
    max_i = np.argmax(probs)
    return sents[max_i], probs[max_i]

# %% [markdown]
# It would be a good idea to retrain your langauge model on all of the Brown sentences (brown.sents()) in order to improve it's recall.
#
# 1. After retraining, do you notice any differences?
